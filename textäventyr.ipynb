# %% [markdown]
# <a href="https://colab.research.google.com/github/Mackan08/Na3a-programmering-riktiga/blob/main/text%C3%A4ventyr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("Vad heter du?")
name = input()
print ("Hej,", name)
#print("Nu ska vi simulera en dag i ditt liv! Är du redo?")
svar = input("Nu ska vi simulera en dag i ditt liv! Är du redo?\nJa/Nej: ")
if svar == "Ja":
  print("Då kör vi!")
else:
  print("Tack för att du spelade")

print("Du vaknar 07.00 på morgonen")
print("Du är trött, snoozar du eller inte?")
svar = input("Ja/Nej")
if svar == "Ja":
  print("Hur många gånger snoozar du?")
  ganger = int(input())
  print("Du snoozar", ganger, "gånger idag")
  print("Du sov i", (ganger*5), "minuter extra")
  print("Din lektion börjar 08:20, Skynda!")
else:
  print("Du går upp ur sängen")

print("Äter du frukost?")
frukost = input("Ja/Nej")

if frukost == "Ja":
  print("Du äter en möglig banan")
  print("Du skyndar dig till bussen")
else:
  print("Du skyndar dig till bussen")

print("Du hinner precis med bussen, flåsandes. Den är full av människor på väg till skolan eller jobbet.")
print("Plötsligt ser du din kompis sitta längst bak. Går du fram och hälsar?")
kompis = input("Ja/Nej")

if kompis == "Ja":
  print("Ni pratar ivrigt om gårdagens spelkväll.")
else:
  print("Du sätter dig ensam vid ett fönster och funderar på dagen.")

print("Bussen stannar vid skolan, och du kastar dig ut.")
print("Klockan är 9:35")
print("Du rör dig mot första lektionen, svenskan.")
print("Efter lektionen är det dags för lunch. Det finns två val, Pizza eller kebab, men vilken ska du välja?")
lunch_choice = input("Pizza/kebab")
if lunch_choice == "Pizza" and "pizza":
  print("Du väljer pizza, det är en vesuvio.")
else:
  print("Du valde kebab, den var god.")

print("Det är dags för dagnes sista lektion, programmering med Jens.")
print("I klassrummet ser du dina två ''kompisar'', Ibrahim och Max. Vem vill du sätta dig bredvid?")
seat_choice = input("Ibrahim/Max")
if seat_choice == "Ibrahim":
  print("Du sätter dig bredvid Ibrahim")
else:
    print("Du sätter dig bredvid Max.")
print("Dagen är nu slut och det är dags att röra sig hemåt, du får skjuts av snälla läraren Jens")
print("På vägen kör han förbi bussfile på vasaplan och ni ger fingret åt A-lagarna vid kuren.")
print("En tiggare kastar en pripps burk på bilen och hjulhängningen går sönder, Ni måste nu slåss mot era fiender.")
player = {"Hp": 100, "attack": 15}
while player ["Hp"] >0:
  print(f"HP: {player['Hp']}")

  tiggarehp = random.randint(20,40)
  tiggareattack = random.randint(5,10)
  while tiggarehp > 0 and player ["Hp"] > 0:
    print(f"Din HP: {player['Hp']}")
    print(f"Tiggarens HP: {tiggarehp}")
    print("\n1. Attackera")
    print("2. Fly")

    action = input("> ")
    if action == "1":

      damage = random.randint(
          player ["attack"] - 5,
          player ["attack"] + 5)

      tiggarehp -= damage

      print(f"Du gör {damage} skada!")

      if tiggarehp > 0:
        damage = random.randint(5, tiggareattack)
        player["Hp"] -= damage
        print (f"Tiggaren gör {damage} skada!")

    elif action == "2":
      print("Du lyckades fly!")
      break

    if tiggarehp <= 0:
      print("Tiggaren är besegrad!")
      break

print("Idag är en speciell dag, det är nämligen valdag till riksdagen. Du och din familj går till vallokalen för att rösta.")
print("Du ställer dig i kön och kommer så småningom längst fram. Du går till ett bås och ska nu välja ditt parti.")
#Idag har jag fixat till lite fel i koden som exempelvis att man alltid valde pizza eller att det alltid kom en ny enemy. Jag skrev även klart fighting-fasen och ändrade lite i storyn innan.
# Out:
# Vad heter du?
# Hej, m
# Tack för att du spelade
# Du vaknar 07.00 på morgonen
# Du är trött, snoozar du eller inte?
# Du går upp ur sängen
# Äter du frukost?
# Du skyndar dig till bussen
# Du hinner precis med bussen, flåsandes. Den är full av människor på väg till skolan eller jobbet.
# Plötsligt ser du din kompis sitta längst bak. Går du fram och hälsar?
# Du sätter dig ensam vid ett fönster och funderar på dagen.
# Bussen stannar vid skolan, och du kastar dig ut.
# Klockan är 9:35
# Du rör dig mot första lektionen, svenskan.
# Efter lektionen är det dags för lunch. Det finns två val, Pizza eller kebab, men vilken ska du välja?
# Du valde kebab, den var god.
# Det är dags för dagnes sista lektion, programmering med Jens.
# I klassrummet ser du dina två ''kompisar'', Ibrahim och Max. Vem vill du sätta dig bredvid?
